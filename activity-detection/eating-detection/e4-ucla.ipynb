# %%
import os
import pandas as pd
input_csv_path = os.path.join("E4-CA.csv")
input_data_set = pd.read_csv(input_csv_path)
input_data_set.head()
# Out:
#            Time  Amplitude-X  Median-X    Mean-X     Max-X     Min-X  \
# 0  18:21:03.212     0.234375  0.234375  0.234375  0.234375  0.234375
# 1  18:21:03.213     0.234375  0.234375  0.234375  0.234375  0.234375
# 2  18:21:03.213     0.218750  0.234375  0.229167  0.234375  0.218750
# 3  18:21:03.213     0.218750  0.234375  0.226562  0.234375  0.218750
# 4  18:21:03.213     0.218750  0.218750  0.225000  0.234375  0.218750
#
#    Peak-to-Peak-X  Variance-X  Std Dev-X     RMS-X  ...    Median-Z    Mean-Z  \
# 0        0.000000    0.000000   0.000000  0.054932  ...    0.953125  0.953125
# 1        0.000000    0.000000   0.000000  0.054932  ...    0.953125  0.953125
# 2        0.015625    0.000081   0.009021  0.052572  ...    0.953125  0.953125
# 3        0.015625    0.000081   0.009021  0.051392  ...    0.953125  0.953125
# 4        0.015625    0.000073   0.008558  0.050684  ...    0.953125  0.956250
#
#       Max-Z     Min-Z  Peak-to-Peak-Z  Variance-Z  Std Dev-Z     RMS-Z  \
# 0  0.953125  0.953125        0.000000    0.000000   0.000000  0.908447
# 1  0.953125  0.953125        0.000000    0.000000   0.000000  0.908447
# 2  0.953125  0.953125        0.000000    0.000000   0.000000  0.908447
# 3  0.953125  0.953125        0.000000    0.000000   0.000000  0.908447
# 4  0.968750  0.953125        0.015625    0.000049   0.006988  0.914453
#
#    Skewness-Z  Label
# 0    0.000000      0
# 1    0.000000      0
# 2    0.000000      0
# 3    0.000000      0
# 4    2.236068      0
#
# [5 rows x 32 columns]

# %%
input_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54858 entries, 0 to 54857
# Data columns (total 32 columns):
# Time              54858 non-null object
# Amplitude-X       54858 non-null float64
# Median-X          54858 non-null float64
# Mean-X            54858 non-null float64
# Max-X             54858 non-null float64
# Min-X             54858 non-null float64
# Peak-to-Peak-X    54858 non-null float64
# Variance-X        54858 non-null float64
# Std Dev-X         54858 non-null float64
# RMS-X             54858 non-null float64
# Skewness-X        54858 non-null float64
# Amplitude-Y       54858 non-null float64
# Median-Y          54858 non-null float64
# Mean-Y            54858 non-null float64
# Max-Y             54858 non-null float64
# Min-Y             54858 non-null float64
# Peak-to-Peak-Y    54858 non-null float64
# Variance-Y        54858 non-null float64
# Std Dev-Y         54858 non-null float64
# RMS-Y             54858 non-null float64
# Skewness-Y        54858 non-null float64
# Amplitude-Z       54858 non-null float64
# Median-Z          54858 non-null float64
# Mean-Z            54858 non-null float64
# Max-Z             54858 non-null float64
# Min-Z             54858 non-null float64
# Peak-to-Peak-Z    54858 non-null float64
# Variance-Z        54858 non-null float64
# Std Dev-Z         54858 non-null float64
# RMS-Z             54858 non-null float64
# Skewness-Z        54858 non-null float64
# Label             54858 non-null int64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 13.4+ MB

# %%
input_data_set.describe()
# Out:
#         Amplitude-X      Median-X        Mean-X         Max-X         Min-X  \
# count  54858.000000  54858.000000  54858.000000  54858.000000  54858.000000
# mean       0.492283      0.354990      0.359042      0.503368      0.228970
# std        0.295074      0.434547      0.432454      0.465910      0.460303
# min        0.000000     -0.875000     -0.876250     -0.609375     -1.281250
# 25%        0.250000      0.062500      0.075000      0.296875     -0.062500
# 50%        0.406250      0.312500      0.311875      0.609375      0.125000
# 75%        0.796875      0.781250      0.773125      0.859375      0.687500
# max        1.984375      1.093750      1.085625      1.984375      0.953125
#
#        Peak-to-Peak-X    Variance-X     Std Dev-X         RMS-X    Skewness-X  \
# count    54858.000000  54858.000000  54858.000000  54858.000000  54858.000000
# mean         0.274398      0.014059      0.076486      0.329421      0.109205
# std          0.319184      0.032662      0.090603      0.291775      1.277196
# min          0.000000      0.000000      0.000000      0.000000     -5.000000
# 25%          0.015625      0.000061      0.007812      0.079482     -0.398655
# 50%          0.187500      0.002131      0.046158      0.170908      0.028302
# 75%          0.406250      0.012836      0.113297      0.615896      0.589223
# max          2.609375      0.704405      0.839288      1.215596      5.000000
#
#            ...           Median-Z        Mean-Z         Max-Z         Min-Z  \
# count      ...       54858.000000  54858.000000  54858.000000  54858.000000
# mean       ...           0.386341      0.386829      0.497854      0.282304
# std        ...           0.238163      0.234729      0.263637      0.258737
# min        ...          -0.718750     -0.715000     -0.656250     -0.875000
# 25%        ...           0.234375      0.235625      0.281250      0.156250
# 50%        ...           0.390625      0.393125      0.531250      0.250000
# 75%        ...           0.515625      0.515625      0.656250      0.453125
# max        ...           1.062500      1.098750      1.609375      0.953125
#
#        Peak-to-Peak-Z    Variance-Z     Std Dev-Z         RMS-Z    Skewness-Z  \
# count    54858.000000  54858.000000  54858.000000  54858.000000  54858.000000
# mean         0.215551      0.008805      0.063500      0.213186     -0.004515
# std          0.231846      0.018458      0.069086      0.187504      1.267771
# min          0.000000      0.000000      0.000000      0.000215     -5.000000
# 25%          0.015625      0.000059      0.007655      0.065337     -0.427734
# 50%          0.156250      0.001530      0.039115      0.171069      0.000000
# 75%          0.343750      0.011058      0.105156      0.273721      0.434783
# max          1.734375      0.296145      0.544192      1.233379      5.000000
#
#               Label
# count  54858.000000
# mean       0.108808
# std        0.311401
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(input_data_set, test_size = 0.2, random_state = 42)

print("Data set length: ", len(input_data_set))
print("Train set length: ", len(train_set), " Percentage of orig. data set length: ", (float(len(train_set)) / len(input_data_set)))
print("Test set length: ", len(test_set), " Percentage of orig. data set length: ", (float(len(test_set)) / len(input_data_set)))
# Out:
# ('Data set length: ', 54858)
# ('Train set length: ', 43886, ' Percentage of orig. data set length: ', 0.7999927084472639)
# ('Test set length: ', 10972, ' Percentage of orig. data set length: ', 0.20000729155273617)

# %%
def get_value_label_matrices(data_set):
    labels = data_set["Label"].copy().values
    values = data_set[[
        "Amplitude-X",
        "Median-X",
        "Mean-X",
        "Max-X",
        "Min-X",
        "Peak-to-Peak-X",
        "Variance-X",
        "Std Dev-X",
        "RMS-X",
        "Skewness-X",
        "Amplitude-Y",
        "Median-Y",
        "Mean-Y",
        "Max-Y",
        "Min-Y",
        "Peak-to-Peak-Y",
        "Variance-Y",
        "Std Dev-Y",
        "RMS-Y",
        "Skewness-Y",
        "Amplitude-Z",
        "Median-Z",
        "Mean-Z",
        "Max-Z",
        "Min-Z",
        "Peak-to-Peak-Z",
        "Variance-Z",
        "Std Dev-Z",
        "RMS-Z",
        "Skewness-Z"
    ]].copy().values
    
    # Sanity check ... the number of value / label records should match
    print("Parsed ", len(values), " values and ", len(labels), " labels")
    return values, labels

# %%
training_values, training_labels = get_value_label_matrices(train_set)
# Out:
# ('Parsed ', 43886, ' values and ', 43886, ' labels')

# %%
test_values, test_labels = get_value_label_matrices(test_set)
# Out:
# ('Parsed ', 10972, ' values and ', 10972, ' labels')

# %%
from sklearn.ensemble import RandomForestClassifier

rfClf = RandomForestClassifier(n_estimators=100)

rfClf = rfClf.fit(training_values, training_labels)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

def generate_predictions_and_cross_validate(clf, values, labels):
    validator_num = 10 # number of validators to use ... feel free to play with this
    
    # generate the predicted labels with the provided classifer ...
    predicted_labels = cross_val_predict(clf, values, labels, cv = validator_num)
    
    # what predictions did the classifier generate?
    actual_predictions = confusion_matrix(labels, predicted_labels)
    print("Actual Predictions: ")
    print(actual_predictions)
    
    # what predictions *SHOULD* the classifier have generated?
    perfect_predictions = confusion_matrix(labels, labels)
    print("Perfect Predictions: ")
    print(perfect_predictions)
    
    # Let's see how we did ...
    score = cross_val_score(clf, values, labels, cv = validator_num, scoring = "accuracy")
    print("Classifier Accuracy: ", score)
    return predicted_labels

# %%
predicted_labels = generate_predictions_and_cross_validate(rfClf, training_values, training_labels)
# Out:
# Actual Predictions:
# [[39040    73]
#  [  123  4650]]
# Perfect Predictions:
# [[39113     0]
#  [    0  4773]]
# ('Classifier Accuracy: ', array([0.99384966, 0.99567198, 0.99703872, 0.99453054, 0.99680948,
#        0.9958979 , 0.99658159, 0.99498633, 0.99521422, 0.99430264]))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(training_labels, predicted_labels)
print("Precision: ", precision)

recall = recall_score(training_labels, predicted_labels)
print("Recall: ", recall)

fscore = f1_score(training_labels, predicted_labels)
print("F Score: ", fscore)
# Out:
# ('Precision: ', 0.9845437222104595)
# ('Recall: ', 0.9742300439974858)
# ('F Score: ', 0.9793597304128053)

# %%
# Once you have the precision, recall, and f-score where you want them,
# you can evaluate the test set as well!

predicted_test_labels = generate_predictions_and_cross_validate(rfClf, test_values, test_labels)

test_precision = precision_score(test_labels, predicted_test_labels)
print("Test Precision: ", test_precision)

test_recall = recall_score(test_labels, predicted_test_labels)
print("Test Recall: ", test_recall)

test_fscore = f1_score(test_labels, predicted_test_labels)
print("Test F-Score: ", test_fscore)
# Out:
# Actual Predictions:
# [[9696   80]
#  [ 146 1050]]
# Perfect Predictions:
# [[9776    0]
#  [   0 1196]]
# ('Classifier Accuracy: ', array([0.97632058, 0.98542805, 0.97814208, 0.9863388 , 0.98360656,
#        0.97723133, 0.97354015, 0.97171533, 0.97080292, 0.98357664]))
# ('Test Precision: ', 0.9292035398230089)
# ('Test Recall: ', 0.8779264214046822)
# ('Test F-Score: ', 0.9028374892519346)
