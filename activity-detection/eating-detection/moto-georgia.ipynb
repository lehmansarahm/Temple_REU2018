# %%
import os
import pandas as pd
input_csv_path = os.path.join("Moto-GA.csv")
input_data_set = pd.read_csv(input_csv_path)
input_data_set.head()
# Out:
#            Time    Mean-X  Variance-X  Skewness-X  Kurtosis-X     RMS-X  \
# 0  18:21:03.241  0.065361    0.000000    0.000000    0.000000  0.004272
# 1  18:21:03.287  0.062093    0.000021    0.000000    0.000000  0.003866
# 2  18:21:03.334  0.059043    0.000039    0.157627    0.000000  0.003512
# 3  18:21:03.378  0.056194    0.000058    0.195255   -1.139200  0.003201
# 4  18:21:03.418  0.053532    0.000079    0.232339   -1.119036  0.002929
#
#      Mean-Y  Variance-Y  Skewness-Y  Kurtosis-Y     RMS-Y    Mean-Z  \
# 0 -0.290763    0.000000    0.000000    0.000000  0.084543  0.051568
# 1 -0.276225    0.000423    0.000000    0.000000  0.076512  0.048990
# 2 -0.262656    0.000764   -0.157627    0.000000  0.069497  0.046583
# 3 -0.249984    0.001151   -0.195254   -1.139200  0.063355  0.044336
# 4 -0.238141    0.001565   -0.232339   -1.119037  0.057963  0.042235
#
#    Variance-Z  Skewness-Z  Kurtosis-Z     RMS-Z  Label
# 0    0.000000    0.000000    0.000000  0.002659      0
# 1    0.000013    0.000000    0.000000  0.002407      0
# 2    0.000024    0.157635    0.000000  0.002186      0
# 3    0.000036    0.195269   -1.139199  0.001993      0
# 4    0.000049    0.232350   -1.119022  0.001823      0

# %%
input_data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1988 entries, 0 to 1987
# Data columns (total 17 columns):
# Time          1988 non-null object
# Mean-X        1988 non-null float64
# Variance-X    1988 non-null float64
# Skewness-X    1988 non-null float64
# Kurtosis-X    1988 non-null float64
# RMS-X         1988 non-null float64
# Mean-Y        1988 non-null float64
# Variance-Y    1988 non-null float64
# Skewness-Y    1988 non-null float64
# Kurtosis-Y    1988 non-null float64
# RMS-Y         1988 non-null float64
# Mean-Z        1988 non-null float64
# Variance-Z    1988 non-null float64
# Skewness-Z    1988 non-null float64
# Kurtosis-Z    1988 non-null float64
# RMS-Z         1988 non-null float64
# Label         1988 non-null int64
# dtypes: float64(15), int64(1), object(1)
# memory usage: 264.1+ KB

# %%
input_data_set.describe()
# Out:
#             Mean-X   Variance-X   Skewness-X   Kurtosis-X        RMS-X  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean      0.001565     0.052755    -0.125233     0.162439     0.063975
# std       0.115475     0.051995     0.828936     1.860784     0.063080
# min      -0.326456     0.000000    -3.172736    -1.912657     0.000009
# 25%      -0.052547     0.008364    -0.584526    -0.984396     0.010575
# 50%       0.000403     0.035974    -0.148381    -0.399187     0.045750
# 75%       0.055436     0.089370     0.421355     0.657628     0.103464
# max       0.394664     0.276980     4.802119    23.652915     0.276148
#
#             Mean-Y   Variance-Y   Skewness-Y   Kurtosis-Y        RMS-Y  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean     -0.001431     0.070067    -0.081283    -0.000692     0.081535
# std       0.119494     0.059623     0.762337     1.719186     0.063281
# min      -0.457674     0.000000    -3.878097    -1.815894     0.000031
# 25%      -0.065282     0.017072    -0.511760    -1.021341     0.032388
# 50%       0.003542     0.061215    -0.076931    -0.474107     0.075381
# 75%       0.066234     0.103884     0.357055     0.470805     0.116855
# max       0.336481     0.342212     3.060627    17.211986     0.329487
#
#             Mean-Z   Variance-Z   Skewness-Z   Kurtosis-Z        RMS-Z  \
# count  1988.000000  1988.000000  1988.000000  1988.000000  1988.000000
# mean      0.000245     0.054071    -0.007283     0.395784     0.058718
# std       0.082545     0.056110     0.976215     3.233178     0.057946
# min      -0.359133     0.000000    -4.824460    -1.837413     0.000015
# 25%      -0.041678     0.008856    -0.506904    -0.949167     0.010226
# 50%      -0.000082     0.039134    -0.007723    -0.469317     0.042106
# 75%       0.045318     0.077495     0.511389     0.509225     0.084373
# max       0.300014     0.303796     3.893103    23.784236     0.293697
#
#              Label
# count  1988.000000
# mean      0.235412
# std       0.424363
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(input_data_set, test_size = 0.2, random_state = 42)

print("Data set length: ", len(input_data_set))
print("Train set length: ", len(train_set), " Percentage of orig. data set length: ", (float(len(train_set)) / len(input_data_set)))
print("Test set length: ", len(test_set), " Percentage of orig. data set length: ", (float(len(test_set)) / len(input_data_set)))
# Out:
# ('Data set length: ', 1988)
# ('Train set length: ', 1590, ' Percentage of orig. data set length: ', 0.7997987927565392)
# ('Test set length: ', 398, ' Percentage of orig. data set length: ', 0.20020120724346077)

# %%
def get_value_label_matrices(data_set):
    labels = data_set["Label"].copy().values
    values = data_set[[
        "Mean-X",
        "Variance-X",
        "RMS-X",
        "Skewness-X",
        "Kurtosis-X",
        "Mean-Y",
        "Variance-Y",
        "RMS-Y",
        "Kurtosis-Y",
        "Skewness-Y",
        "Mean-Z",
        "Variance-Z",
        "RMS-Z",
        "Kurtosis-Z",
        "Skewness-Z"
    ]].copy().values
    
    # Sanity check ... the number of value / label records should match
    print("Parsed ", len(values), " values and ", len(labels), " labels")
    return values, labels

# %%
training_values, training_labels = get_value_label_matrices(train_set)
# Out:
# ('Parsed ', 1590, ' values and ', 1590, ' labels')

# %%
test_values, test_labels = get_value_label_matrices(test_set)
# Out:
# ('Parsed ', 398, ' values and ', 398, ' labels')

# %%
from sklearn.ensemble import RandomForestClassifier

rfClf = RandomForestClassifier(n_estimators=100)

rfClf = rfClf.fit(training_values, training_labels)

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

def generate_predictions_and_cross_validate(clf, values, labels):
    validator_num = 10 # number of validators to use ... feel free to play with this
    
    # generate the predicted labels with the provided classifer ...
    predicted_labels = cross_val_predict(clf, values, labels, cv = validator_num)
    
    # what predictions did the classifier generate?
    actual_predictions = confusion_matrix(labels, predicted_labels)
    print("Actual Predictions: ")
    print(actual_predictions)
    
    # what predictions *SHOULD* the classifier have generated?
    perfect_predictions = confusion_matrix(labels, labels)
    print("Perfect Predictions: ")
    print(perfect_predictions)
    
    # Let's see how we did ...
    score = cross_val_score(clf, values, labels, cv = validator_num, scoring = "accuracy")
    print("Classifier Accuracy: ", score)
    return predicted_labels

# %%
predicted_labels = generate_predictions_and_cross_validate(rfClf, training_values, training_labels)
# Out:
# Actual Predictions:
# [[1198    8]
#  [  35  349]]
# Perfect Predictions:
# [[1206    0]
#  [   0  384]]
# ('Classifier Accuracy: ', array([0.94375   , 0.98125   , 0.98125   , 0.96875   , 0.96226415,
#        0.96226415, 0.96835443, 0.98101266, 0.96835443, 0.98101266]))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(training_labels, predicted_labels)
print("Precision: ", precision)

recall = recall_score(training_labels, predicted_labels)
print("Recall: ", recall)

fscore = f1_score(training_labels, predicted_labels)
print("F Score: ", fscore)
# Out:
# ('Precision: ', 0.9775910364145658)
# ('Recall: ', 0.9088541666666666)
# ('F Score: ', 0.941970310391363)

# %%
# Once you have the precision, recall, and f-score where you want them,
# you can evaluate the test set as well!

predicted_test_labels = generate_predictions_and_cross_validate(rfClf, test_values, test_labels)

test_precision = precision_score(test_labels, predicted_test_labels)
print("Test Precision: ", test_precision)

test_recall = recall_score(test_labels, predicted_test_labels)
print("Test Recall: ", test_recall)

test_fscore = f1_score(test_labels, predicted_test_labels)
print("Test F-Score: ", test_fscore)
# Out:
# Actual Predictions:
# [[311   3]
#  [ 35  49]]
# Perfect Predictions:
# [[314   0]
#  [  0  84]]
# ('Classifier Accuracy: ', array([0.87804878, 0.90243902, 0.92682927, 0.95121951, 0.94871795,
#        0.8974359 , 0.92307692, 0.87179487, 0.84615385, 0.87179487]))
# ('Test Precision: ', 0.9423076923076923)
# ('Test Recall: ', 0.5833333333333334)
# ('Test F-Score: ', 0.7205882352941178)
